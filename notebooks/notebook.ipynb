# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('../artifacts/raw/data.csv')

# %%
df.head()
# Out:
#    Patient_ID Country  Age Gender Cancer_Stage  Tumor_Size_mm Family_History  \
# 0           1      UK   77      M    Localized             69             No
# 1           2      UK   59      M    Localized             33             No
# 2           3   Japan   66      M     Regional             17             No
# 3           4     USA   83      M     Regional             14             No
# 4           5  France   66      M    Localized             34             No
#
#   Smoking_History Alcohol_Consumption Obesity_BMI  ... Survival_5_years  \
# 0              No                 Yes  Overweight  ...              Yes
# 1              No                  No  Overweight  ...              Yes
# 2             Yes                  No      Normal  ...              Yes
# 3              No                  No       Obese  ...              Yes
# 4             Yes                  No      Normal  ...              Yes
#
# ...

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Country', 'Age', 'Gender', 'Cancer_Stage',
#        'Tumor_Size_mm', 'Family_History', 'Smoking_History',
#        'Alcohol_Consumption', 'Obesity_BMI', 'Diet_Risk', 'Physical_Activity',
#        'Diabetes', 'Inflammatory_Bowel_Disease', 'Genetic_Mutation',
#        'Screening_History', 'Early_Detection', 'Treatment_Type',
#        'Survival_5_years', 'Mortality', 'Healthcare_Costs',
#        'Incidence_Rate_per_100K', 'Mortality_Rate_per_100K', 'Urban_or_Rural',
#        'Economic_Classification', 'Healthcare_Access', 'Insurance_Status',
#        'Survival_Prediction'],
#       dtype='object')

# %%
df.Survival_Prediction.value_counts() #understanding the data
# Out:
# Survival_Prediction
# Yes    100437
# No      67060
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Patient_ID                    0
# Country                       0
# Age                           0
# Gender                        0
# Cancer_Stage                  0
# Tumor_Size_mm                 0
# Family_History                0
# Smoking_History               0
# Alcohol_Consumption           0
# Obesity_BMI                   0
# Diet_Risk                     0
# Physical_Activity             0
# Diabetes                      0
# Inflammatory_Bowel_Disease    0
# Genetic_Mutation              0
# Screening_History             0
# Early_Detection               0
# Treatment_Type                0
# Survival_5_years              0
# Mortality                     0
# Healthcare_Costs              0
# Incidence_Rate_per_100K       0
# Mortality_Rate_per_100K       0
# Urban_or_Rural                0
# Economic_Classification       0
# Healthcare_Access             0
# Insurance_Status              0
# Survival_Prediction           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (167497, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167497 entries, 0 to 167496
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Patient_ID                  167497 non-null  int64
#  1   Country                     167497 non-null  object
#  2   Age                         167497 non-null  int64
#  3   Gender                      167497 non-null  object
#  4   Cancer_Stage                167497 non-null  object
#  5   Tumor_Size_mm               167497 non-null  int64
#  6   Family_History              167497 non-null  object
#  7   Smoking_History             167497 non-null  object
#  8   Alcohol_Consumption         167497 non-null  object
#  9   Obesity_BMI                 167497 non-null  object
#  10  Diet_Risk                   167497 non-null  object
#  11  Physical_Activity           167497 non-null  object
#  12  Diabetes                    167497 non-null  object
# ...

# %%
df.describe()
# Out:
#           Patient_ID           Age  Tumor_Size_mm  Healthcare_Costs  \
# count  167497.000000  167497.00000  167497.000000     167497.000000
# mean    83749.000000      69.20078      42.005708      72452.168099
# std     48352.363357      11.87247      21.672206      27402.779597
# min         1.000000      30.00000       5.000000      25000.000000
# 25%     41875.000000      59.00000      23.000000      48760.000000
# 50%     83749.000000      69.00000      42.000000      72344.000000
# 75%    125623.000000      79.00000      61.000000      96227.000000
# max    167497.000000      89.00000      79.000000     119999.000000
#
#        Incidence_Rate_per_100K  Mortality_Rate_per_100K
# count            167497.000000            167497.000000
# mean                 34.531562                17.023875
# std                  14.447970                 7.208766
# min                  10.000000                 5.000000
# 25%                  22.000000                11.000000
# ...

# %% [markdown]
# # Visualizations

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Cancer_Stage',hue='Survival_5_years',data=df,palette='coolwarm')
plt.title("Cancer stage VS survival 5 years")
# Out:
# Text(0.5, 1.0, 'Cancer stage VS survival 5 years')

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Smoking_History',hue='Mortality',data=df,palette='coolwarm')
plt.title("Smoking_History VS Mortality")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Cancer_Stage',y='Tumor_Size_mm',data=df,palette='coolwarm')
plt.title("Tumor size vs cancer stage")
plt.show()
# Out:
# C:\Users\91835\AppData\Local\Temp\ipykernel_34856\3323569999.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Cancer_Stage',y='Tumor_Size_mm',data=df,palette='coolwarm')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Survival_Prediction',y='Healthcare_Costs',data=df,palette='coolwarm')
plt.title("Survival_Prediction vs Healthcare_Costs")
plt.show()
# Out:
# C:\Users\91835\AppData\Local\Temp\ipykernel_34856\621348178.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Survival_Prediction',y='Healthcare_Costs',data=df,palette='coolwarm')

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Cancer_Stage',hue='Survival_Prediction',data=df,palette='coolwarm')
plt.title("Survival_Prediction vs Cancer_Stage")
plt.show()

# %% [markdown]
# ### Data Processing

# %%
df.drop(columns=['Patient_ID'],inplace=True)

# %%
df.shape
# Out:
# (167497, 27)

# %%
X = df.drop(columns=['Survival_Prediction'])

# %%
y = df[['Survival_Prediction']]

# %%
categorical_cols = X.select_dtypes(include=['object']).columns

# %%
categorical_cols
# Out:
# Index(['Country', 'Gender', 'Cancer_Stage', 'Family_History',
#        'Smoking_History', 'Alcohol_Consumption', 'Obesity_BMI', 'Diet_Risk',
#        'Physical_Activity', 'Diabetes', 'Inflammatory_Bowel_Disease',
#        'Genetic_Mutation', 'Screening_History', 'Early_Detection',
#        'Treatment_Type', 'Survival_5_years', 'Mortality', 'Urban_or_Rural',
#        'Economic_Classification', 'Healthcare_Access', 'Insurance_Status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
label_encoders ={}

for col in categorical_cols:
    le=LabelEncoder()
    buf_col= X[col].unique()
    X[col]=le.fit_transform(X[col])
    label_encoders[col] = [le.classes_,X[col].unique()]

# %%
label_encoders
# Out:
# {'Country': [array(['Australia', 'Brazil', 'Canada', 'China', 'France', 'Germany',
#          'India', 'Italy', 'Japan', 'New Zealand', 'Nigeria', 'Pakistan',
#          'South Africa', 'South Korea', 'UK', 'USA'], dtype=object),
#   array([14,  8, 15,  4,  2,  5,  3, 13,  1,  7,  6, 11,  9, 12,  0, 10])],
#  'Gender': [array(['F', 'M'], dtype=object), array([1, 0])],
#  'Cancer_Stage': [array(['Localized', 'Metastatic', 'Regional'], dtype=object),
#   array([0, 2, 1])],
#  'Family_History': [array(['No', 'Yes'], dtype=object), array([0, 1])],
#  'Smoking_History': [array(['No', 'Yes'], dtype=object), array([0, 1])],
#  'Alcohol_Consumption': [array(['No', 'Yes'], dtype=object), array([1, 0])],
#  'Obesity_BMI': [array(['Normal', 'Obese', 'Overweight'], dtype=object),
#   array([2, 0, 1])],
#  'Diet_Risk': [array(['High', 'Low', 'Moderate'], dtype=object),
#   array([1, 2, 0])],
#  'Physical_Activity': [array(['High', 'Low', 'Moderate'], dtype=object),
#   array([1, 2, 0])],
# ...

# %%
X
# Out:
#         Country  Age  Gender  Cancer_Stage  Tumor_Size_mm  Family_History  \
# 0            14   77       1             0             69               0
# 1            14   59       1             0             33               0
# 2             8   66       1             2             17               0
# 3            15   83       1             2             14               0
# 4             4   66       1             0             34               0
# ...         ...  ...     ...           ...            ...             ...
# 167492       15   69       1             0             49               0
# 167493       15   79       0             2             29               1
# 167494       15   74       1             1             62               1
# 167495       14   68       0             0             35               0
# 167496        4   79       0             1             67               1
#
#         Smoking_History  Alcohol_Consumption  Obesity_BMI  Diet_Risk  ...  \
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167497 entries, 0 to 167496
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Country                     167497 non-null  int32
#  1   Age                         167497 non-null  int64
#  2   Gender                      167497 non-null  int32
#  3   Cancer_Stage                167497 non-null  int32
#  4   Tumor_Size_mm               167497 non-null  int64
#  5   Family_History              167497 non-null  int32
#  6   Smoking_History             167497 non-null  int32
#  7   Alcohol_Consumption         167497 non-null  int32
#  8   Obesity_BMI                 167497 non-null  int32
#  9   Diet_Risk                   167497 non-null  int32
#  10  Physical_Activity           167497 non-null  int32
#  11  Diabetes                    167497 non-null  int32
#  12  Inflammatory_Bowel_Disease  167497 non-null  int32
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,random_state=42,test_size=0.2)

# %%
from sklearn.feature_selection import chi2,SelectKBest

# %%
### Feature Selection
# Chi Square test
x_cat = X_train.select_dtypes(include=['int64','float64'])
chi2_selector = SelectKBest(score_func=chi2,k="all")
chi2_selector.fit(x_cat,y_train)
# Out:
# SelectKBest(k='all', score_func=<function chi2 at 0x000002980CF0C0D0>)

# %%
chi2_scores = pd.DataFrame({
    "Feature":x_cat.columns,
    "Chi2 Square":chi2_selector.scores_
}).sort_values(by='Chi2 Square',ascending=False)

# %%
chi2_scores
# Out:
#                    Feature  Chi2 Square
# 2         Healthcare_Costs  2097.430133
# 1            Tumor_Size_mm     7.971461
# 4  Mortality_Rate_per_100K     1.963077
# 0                      Age     0.679739
# 3  Incidence_Rate_per_100K     0.208835

# %%
top_feautres =chi2_scores.head(5)['Feature'].to_list()

# %%
top_feautres
# Out:
# ['Healthcare_Costs',
#  'Tumor_Size_mm',
#  'Mortality_Rate_per_100K',
#  'Age',
#  'Incidence_Rate_per_100K']

# %%
X=X[top_feautres]
X.shape
# Out:
# (167497, 5)

# %%
y_label = LabelEncoder()
y=y_label.fit_transform(y)
# Out:
# c:\Users\91835\OneDrive\Desktop\mlops-5\venv\lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Model Building

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,random_state=42,test_size=0.2,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test =scaler.fit_transform(X_test)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb= GradientBoostingClassifier(n_estimators=10,learning_rate=0.01,max_depth=4,random_state=42)

# %%
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=4, n_estimators=10,
#                            random_state=42)

# %%
y_pred = gb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.5996417910447761

# %% [markdown]
# ### DL model try

# %%
X_test.shape
# Out:
# (33500, 5)

# %%
import tensorflow as tf

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.layers import Dense,Input,BatchNormalization

model = Sequential([
    Dense(32,activation='relu'),
    BatchNormalization(),

    Dense(64,activation='relu'),
    BatchNormalization(),

    Dense(128,activation='relu'),
    BatchNormalization(),

    Dense(64,activation = 'relu'),
    BatchNormalization(),

    Dense(1,activation = 'sigmoid')
])
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['mae','mse','accuracy'],loss= binary_crossentropy)

# %%
model.fit(X_train,y_train,validation_data=[X_test,y_test],epochs=10,)
# Out:
# Epoch 1/10
# 4188/4188 [==============================] - 191s 45ms/step - loss: 0.6832 - mae: 0.4804 - mse: 0.2446 - accuracy: 0.5874 - val_loss: 0.6761 - val_mae: 0.4824 - val_mse: 0.2415 - val_accuracy: 0.5998
# Epoch 2/10
# 4188/4188 [==============================] - 173s 41ms/step - loss: 0.6753 - mae: 0.4802 - mse: 0.2411 - accuracy: 0.5989 - val_loss: 0.6742 - val_mae: 0.4819 - val_mse: 0.2406 - val_accuracy: 0.5996
# Epoch 3/10
#   63/4188 [..............................] - ETA: 3:11 - loss: 0.6742 - mae: 0.4818 - mse: 0.2406 - accuracy: 0.6037
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 model.fit(X_train,y_train,validation_data=[X_test,y_test],epochs=10,)
#
# File c:\Users\91835\OneDrive\Desktop\mlops-5\venv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
# ...

# %% [markdown]
# ### Classification report

# %%
from sklearn.metrics import classification_report,roc_auc_score
report = classification_report(y_test,y_pred)
# Out:
# c:\Users\91835\OneDrive\Desktop\mlops-5\venv\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\91835\OneDrive\Desktop\mlops-5\venv\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\91835\OneDrive\Desktop\mlops-5\venv\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     13412
#            1       0.60      1.00      0.75     20088
#
#     accuracy                           0.60     33500
#    macro avg       0.30      0.50      0.37     33500
# weighted avg       0.36      0.60      0.45     33500

# %%
y_proba = gb.predict_proba(X_test)[ : ,1] if 2 == 2 else None

# %%
roc_auc_score(y_test,y_proba)
# Out:
# 0.5003013990158186

# %%
plt.figure(figsize=(5,5))
plt.barh(top_feautres,gb.feature_importances_)
plt.gca().invert_yaxis()

# %% [markdown]
# ### Testing Prediction

# %%
test_array =np.array([0,0,0,0,0]).reshape(1,-1)

# %%
gb.predict(test_array)
# Out:
# array([1])
